# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
for dirname, _, filenames in os.walk('data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# data\ads.csv
# data\equipements.csv
# data\neighborhood_facilities.csv
# data\transports.csv

# %%
df = pd.read_csv ('data/transports.csv')
df
# Out:
#       type num_line    ad_id
# 0      bus      30"  ad_1917
# 1      bus      31"  ad_1917
# 2      bus      43"  ad_1917
# 3      bus      84"  ad_1917
# 4      bus      92"  ad_1917
# ...    ...      ...      ...
# 11416  bus      74"   ad_534
# 11417  bus      80"   ad_534
# 11418  bus      81"   ad_534
# 11419  bus      95"   ad_534
# 11420  bus      518   ad_534
#
# [11421 rows x 3 columns]

# %%
df["ad_id"].nunique()
# Out:
# 1398

# %%
df['num_line'].unique()
# Out:
# array(['30"', '31"', '43"', '84"', '92"', '93"', 'T3b', '56"', '60"',
#        '137', '166', '302', '341', '12"', '85"', '11"', '20"', '46"',
#        '65"', '69"', '75"', '96"', '26"', '57"', '61"', '64"', '76"',
#        '102', '351', '501', '35"', '48"', '350', '519', '38"', '58"',
#        '68"', '82"', '83"', '89"', '91"', '94"', '95"', '39"', '62"',
#        '70"', '80"', '88"', '27"', '132', '325', '255', '21"', '29"',
#        '42"', '52"', '67"', '74"', '81"', '13"', '54"', '518', '151',
#        '24"', '87"', '22"', '32"', '63"', '72"', '241', '244', '28"',
#        '73"', '47"', 'T3a', '191', 'T2"', '126', '169', '189', '290',
#        '323', '10"', '86"', '14"', '66"', '138', '173', '123', '175',
#        '289', '153', '239', '252', '112', '114', '115', '118', '124',
#        '210', '318', '125', '128', '187', '188', '194', '197', '295',
#        '297', '299', '513', '184', '186', '105', '129', '170', '249',
#        '109', '111', '53"', '163', '164', '165', 'T9"', '131', '183',
#        '185', '215'], dtype=object)

# %%
df['num_line'].str.replace('"', '').unique()
# Out:
# array(['30', '31', '43', '84', '92', '93', 'T3b', '56', '60', '137',
#        '166', '302', '341', '12', '85', '11', '20', '46', '65', '69',
#        '75', '96', '26', '57', '61', '64', '76', '102', '351', '501',
#        '35', '48', '350', '519', '38', '58', '68', '82', '83', '89', '91',
#        '94', '95', '39', '62', '70', '80', '88', '27', '132', '325',
#        '255', '21', '29', '42', '52', '67', '74', '81', '13', '54', '518',
#        '151', '24', '87', '22', '32', '63', '72', '241', '244', '28',
#        '73', '47', 'T3a', '191', 'T2', '126', '169', '189', '290', '323',
#        '10', '86', '14', '66', '138', '173', '123', '175', '289', '153',
#        '239', '252', '112', '114', '115', '118', '124', '210', '318',
#        '125', '128', '187', '188', '194', '197', '295', '297', '299',
#        '513', '184', '186', '105', '129', '170', '249', '109', '111',
#        '53', '163', '164', '165', 'T9', '131', '183', '185', '215'],
#       dtype=object)

# %%
df['type'].unique()
# Out:
# array(['bus', 'metro'], dtype=object)

# %%
df = df.groupby(['ad_id','type']).size().unstack(level=1)

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
# type      bus  metro
# ad_id
# ad_0      7.0    1.0
# ad_1      7.0    1.0
# ad_10    17.0    0.0
# ad_1006  12.0    0.0
# ad_1007  12.0    0.0
# ...       ...    ...
# ad_995    6.0    0.0
# ad_996    6.0    0.0
# ad_997    4.0    0.0
# ad_998    4.0    0.0
# ad_999    4.0    0.0
#
# [1398 rows x 2 columns]

# %%
#df.groupby(['ad_id','type']).size().reset_index(name='counts')

# %%
ads = pd.read_csv ('data/ads.csv')

# %%
ads
# Out:
#            id                                        description  \
# 0     ad_1917  PARIS 17ème. AVENUE NIEL *** Vidéo disponible ...
# 1     ad_1454  Appartement Paris 3 pièce(s) 53 m2. Stéphane P...
# 2     ad_1794  Vente Appartement 2 pièces de 31m² - 75018 Par...
# 3     ad_1519  A vendre, en exclusivité, dans le 11e arrondis...
# 4     ad_1779  Gambetta 2 pièce(s) 40 m2. Rue d'Annam, à quel...
# ...       ...                                                ...
# 1870   ad_741  Appartement familial - Nation. Le Groupe H&amp...
# 1871  ad_1600  Village de Passy - 5 pièces - 195,51 m². Villa...
# 1872  ad_1441  Appartement 2 pièces de 46m² | Rue Clisson | P...
# 1873   ad_380  Duplex 3 pièces avec terrasse - Pernety XVIème...
# 1874   ad_534  PARIS 18EME -AVE CLICHY-Idéal 1er achat. PARIS...
#
#                                                  adress  \
# 0     Achat appartement 2 pièces 63 m²Paris 17e 7501...
# 1     Achat appartement 3 pièces 53 m²Paris 18e 7501...
# 2     Achat appartement 2 pièces 31 m²Paris 18e 7501...
# 3     Achat appartement 2 pièces 31 m²Paris 11e 7501...
# 4     Achat appartement 2 pièces 40 m²Paris 20e 7502...
# ...                                                 ...
# 1870  Achat appartement 6 pièces 168 m²Paris 12e 750...
# 1871  Achat appartement 5 pièces 200 m²Paris 16e 750...
# 1872  Achat appartement 2 pièces 46 m²Paris 13e 7501...
# 1873  Achat duplex 3 pièces 53 m²Paris 14e 75014 (Pe...
# 1874  Achat appartement 1 pièce 13 m²Paris 18e 75018...
#
#                            date_pub               date_update        price  \
# 0            Publiée le 4 déc. 2021  Modifiée le 30 déc. 2021    640 000 €
# 1           Publiée le 16 déc. 2021  Modifiée le 16 déc. 2021    556 500 €
# 2            Publiée le 8 déc. 2021  Modifiée le 28 déc. 2021    305 000 €
# 3           Publiée le 15 déc. 2021  Modifiée le 29 déc. 2021    380 000 €
# 4           Publiée le 24 nov. 2021  Modifiée le 29 déc. 2021    368 000 €
# ...                             ...                       ...          ...
# 1870  Publiée il y a plus de 2 mois  Modifiée le 29 déc. 2021  1 697 000 €
# 1871        Publiée le 14 déc. 2021                       NaN  2 370 000 €
# 1872        Publiée le 16 déc. 2021                       NaN    441 000 €
# 1873  Publiée il y a plus de 2 mois  Modifiée le 18 déc. 2021    785 000 €
# 1874        Publiée le 24 nov. 2021  Modifiée le 18 déc. 2021    165 000 €
#
#                                                     fee
# 0                     Honoraires à la charge du vendeur
# 1     Honoraires : 5,00% TTC inclus à la charge de l...
# 2                     Honoraires à la charge du vendeur
# 3     Honoraires : 4,40% TTC inclus à la charge de l...
# 4     Honoraires : 5,14% TTC inclus à la charge de l...
# ...                                                 ...
# 1870  Honoraires : 1,62% TTC inclus à la charge de l...
# 1871  Honoraires : 3,04% TTC inclus à la charge de l...
# 1872                  Honoraires à la charge du vendeur
# 1873  Honoraires : 4,67% TTC inclus à la charge de l...
# 1874                  Honoraires à la charge du vendeur
#
# [1875 rows x 7 columns]

# %%
merged = pd.merge(ads, df, right_index=True, left_on='id', how='left')

# %%
merged
# Out:
#            id                                        description  \
# 0     ad_1917  PARIS 17ème. AVENUE NIEL *** Vidéo disponible ...
# 1     ad_1454  Appartement Paris 3 pièce(s) 53 m2. Stéphane P...
# 2     ad_1794  Vente Appartement 2 pièces de 31m² - 75018 Par...
# 3     ad_1519  A vendre, en exclusivité, dans le 11e arrondis...
# 4     ad_1779  Gambetta 2 pièce(s) 40 m2. Rue d'Annam, à quel...
# ...       ...                                                ...
# 1870   ad_741  Appartement familial - Nation. Le Groupe H&amp...
# 1871  ad_1600  Village de Passy - 5 pièces - 195,51 m². Villa...
# 1872  ad_1441  Appartement 2 pièces de 46m² | Rue Clisson | P...
# 1873   ad_380  Duplex 3 pièces avec terrasse - Pernety XVIème...
# 1874   ad_534  PARIS 18EME -AVE CLICHY-Idéal 1er achat. PARIS...
#
#                                                  adress  \
# 0     Achat appartement 2 pièces 63 m²Paris 17e 7501...
# 1     Achat appartement 3 pièces 53 m²Paris 18e 7501...
# 2     Achat appartement 2 pièces 31 m²Paris 18e 7501...
# 3     Achat appartement 2 pièces 31 m²Paris 11e 7501...
# 4     Achat appartement 2 pièces 40 m²Paris 20e 7502...
# ...                                                 ...
# 1870  Achat appartement 6 pièces 168 m²Paris 12e 750...
# 1871  Achat appartement 5 pièces 200 m²Paris 16e 750...
# 1872  Achat appartement 2 pièces 46 m²Paris 13e 7501...
# 1873  Achat duplex 3 pièces 53 m²Paris 14e 75014 (Pe...
# 1874  Achat appartement 1 pièce 13 m²Paris 18e 75018...
#
#                            date_pub               date_update        price  \
# 0            Publiée le 4 déc. 2021  Modifiée le 30 déc. 2021    640 000 €
# 1           Publiée le 16 déc. 2021  Modifiée le 16 déc. 2021    556 500 €
# 2            Publiée le 8 déc. 2021  Modifiée le 28 déc. 2021    305 000 €
# 3           Publiée le 15 déc. 2021  Modifiée le 29 déc. 2021    380 000 €
# 4           Publiée le 24 nov. 2021  Modifiée le 29 déc. 2021    368 000 €
# ...                             ...                       ...          ...
# 1870  Publiée il y a plus de 2 mois  Modifiée le 29 déc. 2021  1 697 000 €
# 1871        Publiée le 14 déc. 2021                       NaN  2 370 000 €
# 1872        Publiée le 16 déc. 2021                       NaN    441 000 €
# 1873  Publiée il y a plus de 2 mois  Modifiée le 18 déc. 2021    785 000 €
# 1874        Publiée le 24 nov. 2021  Modifiée le 18 déc. 2021    165 000 €
#
#                                                     fee   bus  metro
# 0                     Honoraires à la charge du vendeur   6.0    0.0
# 1     Honoraires : 5,00% TTC inclus à la charge de l...   7.0    0.0
# 2                     Honoraires à la charge du vendeur   5.0    1.0
# 3     Honoraires : 4,40% TTC inclus à la charge de l...   7.0    1.0
# 4     Honoraires : 5,14% TTC inclus à la charge de l...  12.0    0.0
# ...                                                 ...   ...    ...
# 1870  Honoraires : 1,62% TTC inclus à la charge de l...   NaN    NaN
# 1871  Honoraires : 3,04% TTC inclus à la charge de l...   NaN    NaN
# 1872                  Honoraires à la charge du vendeur   6.0    0.0
# 1873  Honoraires : 4,67% TTC inclus à la charge de l...   4.0    1.0
# 1874                  Honoraires à la charge du vendeur   9.0    1.0
#
# [1875 rows x 9 columns]

# %%
nf = pd.read_csv ('data/neighborhood_facilities.csv')

# %%
nf
# Out:
#                          name  number    ad_id
# 0                         Bar       4  ad_1917
# 1                  Restaurant      54  ad_1917
# 2         Monument historique       5  ad_1917
# 3                     Théâtre       1  ad_1917
# 4      Parc, Jardin et Square       2  ad_1917
# ...                       ...     ...      ...
# 37214                  Vélib'       7   ad_534
# 37215                 Hôpital       1   ad_534
# 37216     Médecin généraliste      20   ad_534
# 37217     Médecin spécialiste      19   ad_534
# 37218               Pharmacie      11   ad_534
#
# [37219 rows x 3 columns]

# %%
nf = nf.groupby(['ad_id','name'])['number'].aggregate('first').unstack()

# %%
nf.fillna(0, inplace=True)

# %%
nf
# Out:
# name     Autolib'  Banque   Bar  Boucherie  Boulangerie  Bureau de poste  \
# ad_id
# ad_0          3.0     6.0   4.0        2.0          7.0              2.0
# ad_1          3.0     6.0   4.0        2.0          7.0              2.0
# ad_10         5.0    10.0   5.0        4.0          9.0              1.0
# ad_1006       5.0     3.0  16.0        1.0          8.0              2.0
# ad_1007       5.0     3.0  16.0        1.0          8.0              2.0
# ...           ...     ...   ...        ...          ...              ...
# ad_995        5.0     6.0   5.0        2.0          4.0              1.0
# ad_996        5.0     6.0   5.0        2.0          4.0              1.0
# ad_997        4.0     3.0   4.0        3.0         10.0              2.0
# ad_998        4.0     3.0   4.0        3.0         10.0              2.0
# ad_999        4.0     3.0   4.0        3.0         10.0              2.0
#
# name     Cinéma  Collège  Crèche  Ecole maternelle  ...  Presse et Tabac  \
# ad_id                                               ...
# ad_0        0.0      8.0     3.0               3.0  ...              3.0
# ad_1        0.0      8.0     3.0               3.0  ...              3.0
# ad_10       0.0      2.0     2.0               5.0  ...              4.0
# ad_1006     1.0      0.0     4.0               3.0  ...              4.0
# ad_1007     1.0      0.0     4.0               3.0  ...              4.0
# ...         ...      ...     ...               ...  ...              ...
# ad_995      2.0      3.0     7.0               6.0  ...              1.0
# ad_996      2.0      3.0     7.0               6.0  ...              1.0
# ad_997      0.0      4.0     8.0               3.0  ...              0.0
# ad_998      0.0      4.0     8.0               3.0  ...              0.0
# ad_999      0.0      4.0     8.0               3.0  ...              0.0
#
# name     Restaurant  Salle de musculation / cardiotraining  Station de taxi  \
# ad_id
# ad_0           19.0                                    0.0              0.0
# ad_1           19.0                                    0.0              0.0
# ad_10          34.0                                    1.0              2.0
# ad_1006        48.0                                    0.0              0.0
# ad_1007        48.0                                    0.0              0.0
# ...             ...                                    ...              ...
# ad_995         24.0                                    2.0              4.0
# ad_996         24.0                                    2.0              4.0
# ad_997         31.0                                    0.0              1.0
# ad_998         31.0                                    0.0              1.0
# ad_999         31.0                                    0.0              1.0
#
# name     Station service  Supermarché et Hypermarché  Supérette  \
# ad_id
# ad_0                 0.0                         7.0        5.0
# ad_1                 0.0                         7.0        5.0
# ad_10                1.0                        10.0        5.0
# ad_1006              0.0                        11.0        6.0
# ad_1007              0.0                        11.0        6.0
# ...                  ...                         ...        ...
# ad_995               0.0                        11.0        6.0
# ad_996               0.0                        11.0        6.0
# ad_997               0.0                         7.0        5.0
# ad_998               0.0                         7.0        5.0
# ad_999               0.0                         7.0        5.0
#
# name     Terrain et Salle de sport  Théâtre  Vélib'
# ad_id
# ad_0                           6.0      1.0     6.0
# ad_1                           6.0      1.0     6.0
# ad_10                          7.0      0.0     9.0
# ad_1006                        4.0      2.0    10.0
# ad_1007                        4.0      2.0    10.0
# ...                            ...      ...     ...
# ad_995                        11.0      1.0     8.0
# ad_996                        11.0      1.0     8.0
# ad_997                         7.0      2.0     7.0
# ad_998                         7.0      2.0     7.0
# ad_999                         7.0      2.0     7.0
#
# [1398 rows x 34 columns]

# %%
merged = pd.merge(merged, nf, right_index=True, left_on='id', )

# %%
merged.columns
# Out:
# Index(['id', 'description', 'adress', 'date_pub', 'date_update', 'price',
#        'fee', 'bus', 'metro', 'Autolib'', 'Banque', 'Bar', 'Boucherie',
#        'Boulangerie', 'Bureau de poste', 'Cinéma', 'Collège', 'Crèche',
#        'Ecole maternelle', 'Ecole primaire', 'Enseignement supérieur',
#        'Gare ferroviaire', 'Hôpital', 'Location de vélo', 'Ludothèque',
#        'Lycée', 'Marché de quartier', 'Monument historique',
#        'Médecin généraliste', 'Médecin spécialiste', 'Parc, Jardin et Square',
#        'Parking', 'Pharmacie', 'Presse et Tabac', 'Restaurant',
#        'Salle de musculation / cardiotraining', 'Station de taxi',
#        'Station service', 'Supermarché et Hypermarché', 'Supérette',
#        'Terrain et Salle de sport', 'Théâtre', 'Vélib''],
#       dtype='object')

# %%
drop_low_corr = ["Autolib'",
 'Bar',
 'Boucherie',
 'Boulangerie',
 'Bureau de poste',
 'Cinéma',
 'Collège',
 'Crèche',
 'Ecole maternelle',
 'Ecole primaire',
 'Enseignement supérieur',
 'Gare ferroviaire',
 'Hôpital',
 'Location de vélo',
 'Ludothèque',
 'Lycée',
 'Marché de quartier',
 'Médecin généraliste',
 'Pharmacie',
 'Restaurant',
 'Station service',
 'Supermarché et Hypermarché',
 'Supérette',
 'Terrain et Salle de sport',
 'Théâtre',
 "Vélib'",
 'Banque',
 'Monument historique',
 'Parking',
 'Presse et Tabac',
 'Salle de musculation / cardiotraining',
 'Station de taxi',]

# %%
#merged.drop(merged[drop_low_corr], axis=1)

# %%
df_equi = pd.read_csv ('data/equipements.csv')
df_equi
# Out:
#          ad_id                        value
# 0      ad_1917                     62,54 m²
# 1      ad_1917                     2 pièces
# 2      ad_1917                    1 chambre
# 3      ad_1917  Chauffage : Individuel  Gaz
# 4      ad_1917                       1 cave
# ...        ...                          ...
# 20509   ad_534                      1 pièce
# 20510   ad_534                    1 chambre
# 20511   ad_534     Chauffage : électricité
# 20512   ad_534                1 salle d’eau
# 20513   ad_534                     5e étage
#
# [20514 rows x 2 columns]

# %%
df_equi["value"].str.replace(u'\xa0', u' ').unique()
# Out:
# array(['62,54 m²', '2 pièces', '1 chambre', 'Chauffage : Individuel  Gaz',
#        '1 cave', '1 cheminée', '1 salle d’eau', '1 WC', 'Rez-de-chaussée',
#        'Construit en 1925', 'Ascenseur', 'Digicode', 'Interphone',
#        '53 m²', '3 pièces', 'Exposé Ouest', 'Cave', 'Fibre : déployée*',
#        'Disponible le 15 mars 2022', '6 étages', 'Construit en 1860',
#        '31 m²', 'Chauffage : Electric', 'Dernier étage (sur 5)',
#        'Construit en 1949', '31,25 m²', 'Exposé Est', '1er étage (sur 5)',
#        'Construit en 1870', '40 m²', 'Récent', '1 salle de bain', 'Calme',
#        '1er étage (sur 8)', 'Construit en 1969', 'Gardien', '51,05 m²',
#        '2 chambres', '1 balcon', 'Chauffage : individuel',
#        '1er étage (sur 6)', '44 m²', 'Balcon', '5e étage (sur 7)',
#        '86 m²', '4 pièces', 'Duplex', '2 salles d’eau', '2 WC', '20 m²',
#        'Terrasse', 'Exposé Sud', '52 m²', '5 étages', 'Construit en 1950',
#        'Exposé Nord Sud', 'Chauffage : gaz individuel', '70,44 m²',
#        'WC séparés', '1 parking intérieur', '1 place de parking',
#        '19e étage', '39 m²', '1 terrasse', 'Construit en 1900',
#        '57,30 m²', 'Construit en 1890', '54,78 m²',
#        'Chauffage : individuel ', '4 étages', '59 m²', '2e étage (sur 9)',
#        '34,50 m²', 'Construit en 1700', '58 m²', '26 m²', '1 pièce',
#        'Travaux à prévoir', 'Exposé Sud Sud Est', 'Chauffage : Gaz',
#        'Dernier étage (sur 12)', 'Construit en 1971', '50 m²',
#        'Construit en 1996', '215 m²', '6 pièces', '3 chambres',
#        '3 salles de bain', 'Dernier étage (sur 4)', '37,02 m²',
#        'Construit en 2002', '66,52 m²', 'Chauffage : Radiateur Gaz ',
#        '117,42 m²', '5 pièces', '4 chambres', 'Cheminée', '4e étage',
#        '70 m²', 'Chauffage : collectif ', '8 étages', 'Construit en 1961',
#        '92 m²', '73,29 m²', 'Aménagement pour Handicapés', '1 box',
#        '1er étage (sur 7)', 'Construit en 1990', '73,50 m²', '2 balcons',
#        'Climatisation', '39,60 m²', '2e étage (sur 4)', '62 m²', '65 m²',
#        '5e étage (sur 6)', '89 m²', '3e étage (sur 5)', '90 m²', 'Jardin',
#        'Exposé Sud Est', '78,21 m²', 'Exposé Est Ouest',
#        '3e étage (sur 6)', 'Construit en 1868', '80 m²',
#        'Chauffage : gaz collectif ', '23 m²', '60 m²',
#        'Chauffage : collectif', '78 m²', '4e étage (sur 7)', '53,42 m²',
#        '4e étage (sur 5)', 'Chauffage : gaz individuel ', '6e étage',
#        '95 m²', 'Exposé Nord', 'Alarme', '49,20 m²', '2e étage (sur 8)',
#        'Construit en 1974', '27,50 m²', 'Construit en 1970', '62,30 m²',
#        'Construit en 1929', '107 m²', '2 salles de bain', '38 m²',
#        'Construit en 1872', 'Exposé Sud Ouest', 'Construit en 1930',
#        '18 m² de terrain', 'Construit en 1916', '124,12 m²', '7 étages',
#        'Construit en 1928', '34 m²', 'Chauffage : gaz collectif',
#        '2e étage (sur 6)', '27 m²', 'Chauffage : électricité ',
#        'Dernier étage (sur 3)', '28,20 m²', 'Chauffage : Individuel',
#        'Fibre : déploiement planifié*', '47 m²', '73 m²',
#        '2e étage (sur 7)', '155 m²', '3 WC', 'Construit en 1934',
#        '212 m²', '2e étage (sur 5)', '24 m²', '6e étage (sur 7)',
#        'Chauffage : radiateur ', '8e étage (sur 9)', '170 m²', '57 m²',
#        'Construit en 1820', '43 m²', '153,87 m²', 'Dernier étage (sur 6)',
#        '35,10 m²', '22 m²', 'Chauffage : électrique ', '5e étage',
#        'Construit en 1899', '30 m²', 'Construit en 1910', '176 m²',
#        '2e étage', 'Construit en 1895', 'Construit en 1850', '42,10 m²',
#        '47,45 m²', '85,80 m²', '6e étage (sur 8)', 'Construit en 1967',
#        '300 m²', '80 m² de terrain', '7 pièces', '5 chambres',
#        '1er étage (sur 3)', '108 m²', '87 m²', '4e étage (sur 6)',
#        '55 m²', '7e étage (sur 12)', 'Construit en 1973', '46,50 m²',
#        'Construit en 1913', '49 m²', '57,01 m²', '11 étages', '32 m²',
#        '63 m²', 'Construit en 1940', '59,42 m²',
#        'Disponible le 23 juillet 2024', '140 m²', '48,63 m²',
#        'Construit en 1880', '7e étage (sur 9)', '18 m²', '53,16 m²',
#        '81 m²', '1er étage', '42 m²', 'Chauffage : Radiateur ',
#        '25,15 m²', 'Dernier étage (sur 7)', 'Construit en 1932', '71 m²',
#        'Chauffage : gaz ', '67 m²', 'Chauffage : Gaz Individuel ',
#        '2 caves', '41,02 m²', '3e étage (sur 4)', 'Construit en 1800',
#        '97 m²', '38,05 m²', '64,40 m²', '69 m²', '86,66 m²', '133 m²',
#        '3 salles d’eau', 'Construit en 1960', '85 m²', '3e étage',
#        '39,04 m²', 'Construit en 1914', '40,76 m²', 'Terrasse de 10 m²',
#        '7e étage (sur 8)', '46,18 m²', 'Construit en 1987', '23,79 m²',
#        'Exposé Nord Ouest', 'Construit en 1896', '73,83 m²',
#        'Balcon de 2 m²', 'Construit en 1980', '160 m²', '149 m²', '96 m²',
#        'Exposé Traversant Est Ouest', '61 m²', 'Exposé Nord Est',
#        '52,41 m²', 'Construit en 1977', '125 m²', '2e étage (sur 16)',
#        '26,13 m²', '110 m²', 'Construit en 1897', '14 m²',
#        'Dernier étage (sur 8)', '32,05 m²', '75 m²', '98 m²', '25 m²',
#        '6 balcons (5 m²)', '108,89 m²', '4e étage (sur 8)',
#        'Construit en 1912', '48 m²', 'Construit en 1976', '51 m²',
#        '48,01 m²', '34,32 m²', '3e étage (sur 7)', 'Construit en 1785',
#        '46 m²', 'Construit en 1905', '1er étage (sur 4)', '116 m²',
#        'Refait à neuf', 'Construit en 1505', '47,27 m²',
#        'Chauffage : mixte', '34,19 m²', 'Construit en 2011', '55,01 m²',
#        'Disponible le 1 juillet 2022', '72,03 m²', '111,35 m²',
#        '4e étage (sur 10)', 'Construit en 2007', '17 m²', '40,50 m²',
#        '100 m²', '5e étage (sur 8)', '172 m²', '169 m²', '7 m²', '190 m²',
#        '130 m²', 'Balcon de 16 m²', '59,59 m²', '3e étage (sur 8)',
#        'Construit en 1933', '4 m² de terrain', '87,20 m²',
#        '18e étage (sur 31)', '58,31 m²', '94,09 m²',
#        'Chauffage : Collectif', '9e étage (sur 10)', 'Construit en 1963',
#        '36 m²', '82 m²', '5e étage (sur 30)', '120 m²', '8e étage',
#        '62,56 m²', '2 places de parking', '45,10 m²',
#        'Chauffage : fuel collectif', '102 m²', 'Exposé Nord Nord Est',
#        'Construit en 1892', '76 m²', '15,58 m²', '36,02 m²',
#        'Construit en 1936', '8e étage (sur 11)', '33,50 m²',
#        '37 m² de terrain', '11 m²', '43,92 m²', '2 étages', '72 m²',
#        '23,47 m²', '3e étage (sur 9)', '2e étage (sur 30)',
#        'Construit en 1962', '15,48 m²', '45 m²', '98,36 m²', '49,75 m²',
#        'Construit en 2001', '2 m² de terrain', '31,01 m²', '38,51 m²',
#        '48,31 m²', '19 m² de terrain', '2 terrasses', 'Construit en 1920',
#        '54,49 m²', 'Chauffage : mixte collectif ', '50,08 m²', '51,06 m²',
#        '6 m²', '57,31 m²', '68 m²', '66 m²', '135 m²', '33 m²',
#        '115,91 m²', '4 cheminées', '124,04 m²', 'Construit en 1906',
#        '20,50 m²', 'Câble TV', '101 m²', 'Construit en 1634', '37 m²',
#        '88 m²', 'Construit en 1964', '71,55 m²', '84 m²',
#        'Dernier étage (sur 2)', '6,80 m²', '83,50 m²', '115 m²',
#        'Construit en 1968', '4e étage (sur 11)', '29,64 m²', '59,44 m²',
#        'Disponible le 15 août 2023', '87,50 m²', '180 m²', '33,01 m²',
#        '2e étage (sur 3)', '999e étage', 'Visiophone', '54,11 m²',
#        '56,53 m²', '1er étage (sur 9)', 'Construit en 1957', '74 m²',
#        '56 m²', 'Balcon de 9 m²', 'Construit en 1966',
#        '3e étage (sur 10)', '76,85 m²', '103,90 m²', 'Construit en 1937',
#        '25,30 m²', 'Construit en 1883', '40,70 m²', 'Construit en 2015',
#        '22,26 m²', '5e étage (sur 11)', '75,41 m²', '21e étage (sur 32)',
#        '13,50 m²', '1er étage (sur 16)', '69,31 m²', '79 m²', '193 m²',
#        '35 m²', '44,61 m²', '65,50 m²', '1 étage', '28 m²', '203 m²',
#        '150 m²', '440 m²', '230 m² de terrain', '11 pièces', '9 chambres',
#        '3 terrasses', 'Piscine', '416 m²', '9 pièces', '4 salles d’eau',
#        '5 WC', '91,31 m²', '29 m²', '168 m²', '5 balcons (40 m²)',
#        '2e étage (sur 14)', '47,08 m²', '35,08 m²', '41 m²', '59,89 m²',
#        'Vue dégagée', 'Construit en 1730', '14,33 m²', '3 étages',
#        'Balcon de 3 m²', 'Construit en 1986', '-1e étage', '40,12 m²',
#        'Chauffage : sol collectif ', 'Construit en 1965', '56,65 m²',
#        '28,68 m²', '89,51 m²', '106 m²', '80,26 m²', '194,44 m²',
#        '8 pièces', '80,04 m²', 'Construit en 1830', '16 m²',
#        'Dernier étage (sur 1)', '65,03 m²', '9e étage', '39,55 m²',
#        'Parquet', '112 m²', '29,55 m²', '21,51 m²', '9,01 m²', '67,07 m²',
#        '89,50 m²', '175 m²', '123,65 m²', '62,17 m²', '171,24 m²',
#        '6 chambres', '4 WC', '30,75 m²', '83 m²',
#        'Chauffage : fuel collectif ', '93,10 m²', '60,15 m²',
#        '3e étage (sur 13)', '177 m²', '20,74 m²', '264,23 m²',
#        'Dernier étage (sur 10)', '53,03 m²', '52,25 m²', '57,80 m²',
#        '64 m²', '105,36 m²', '46,01 m²', 'Chauffage : Collectif  Urbain',
#        '94,51 m²', '23e étage (sur 30)', '41,25 m²', '28,66 m²',
#        '96,82 m²', '52,09 m²', '13 m²', 'Disponible le 30 avril 2022',
#        'Construit en 1993', 'Disponible le 1 août 2023',
#        'Construit en 1972', 'Construit en 1917', '121 m²',
#        '-1e étage (sur 1)', '54 m²', '27,85 m²', 'Construit en 1875',
#        '46,14 m²', 'Construit en 1891', '107,34 m²', '34 m² de terrain',
#        '46,80 m²', '53,78 m²', 'Construit en 1981', '79,50 m²',
#        'Construit en 1994', '88,66 m²', '55,29 m²', '158 m²', '126,09 m²',
#        'Garage', '126 m²', '130,82 m²', '123 m²', 'Balcon de 24 m²',
#        'Construit en 1989', '28 m² de terrain', '4 balcons', '64,20 m²',
#        'Construit en 1999', '61,68 m²', 'Exposé Traversant', '99,17 m²',
#        '41,74 m²', '56,35 m²', 'Balcon de 8 m²', '10 m² de terrain',
#        '111 m²', '46,69 m²', '81 chambres', '7e étage', '117 m²',
#        '3e étage (sur 11)', '10,07 m²', '250 m²', '84,53 m²', '210 m²',
#        '164 m²', '1er étage (sur 2)', '102,54 m²', '50 m² de terrain',
#        'Chauffage : mixte individuel ', '6 m² de terrain',
#        'Résidence étudiants', '150 m² de terrain', 'Construit en 1927',
#        '7e étage (sur 11)', 'Construit en 1952', '14,20 m²',
#        'Chauffage : Central Collectif ', '198 m²', '157 m²',
#        '4 salles de bain', '40,61 m²', 'Construit en 1873',
#        '140 m² de terrain', '53,45 m²', '145,18 m²', 'Construit en 1801',
#        '26,48 m²', 'Construit en 1978', '64,55 m²', '3 balcons', '93 m²',
#        '11e étage (sur 15)', '200 m²', '3 m² de terrain', '10e étage',
#        '115,27 m²', 'Construit en 1901', '3 cheminées', '65,40 m²',
#        'Exposé Sud Est Ouest', '232 m²', '39,02 m²', 'Construit en 1988',
#        '31,37 m²', '83,51 m²', '12 étages', '7,68 m²', '52,85 m²',
#        '21 m²', '133,98 m²', '70,10 m²', '280 m²', '58,94 m²',
#        'Construit en 1851', '73,22 m²', '50,68 m²', '24,31 m²', '91 m²',
#        '232,62 m²', '2 balcons (13 m²)', '48,03 m²', '28,67 m²', '165 m²',
#        '8 m² de terrain', '220 m²', '69,67 m²', '109 m²',
#        '14e étage (sur 31)', 'Exposé SUD NORD', '240 m²',
#        '240 m² de terrain', 'Chauffage : radiateur gaz ',
#        'Chauffage : Collectif gaz', 'Exposé Nord Est Sud', '118,52 m²',
#        '129 m²'], dtype=object)

# %%
df_equi["value"].str.replace(u'\xa0', u' ').str.extract('([a-zA-ZÀ-ÿ]{2,})')[0].str.lower().value_counts()
# Out:
# salle            1736
# pièces           1665
# wc               1427
# fibre            1354
# cave             1110
# ascenseur        1045
# chambres          984
# étage             880
# digicode          836
# construit         826
# chauffage         759
# interphone        755
# exposé            721
# chambre           714
# gardien           501
# calme             496
# er                297
# balcon            278
# salles            235
# rez               218
# cheminée          217
# étages            214
# pièce             210
# dernier           195
# terrasse          170
# place             159
# récent            119
# aménagement        73
# jardin             66
# de                 60
# box                39
# climatisation      39
# balcons            33
# duplex             33
# travaux            29
# alarme             29
# terrasses          24
# disponible         20
# places             20
# refait              9
# visiophone          9
# cheminées           6
# câble               6
# parking             6
# piscine             5
# parquet             3
# garage              3
# résidence           3
# caves               3
# vue                 3
# Name: 0, dtype: int64

# %%
column_with_value = {
#    "parking" : ["parking", "(\d{1})"],
    "built" : ["Construit", "(\d{4})"],
    "stage" : ["étage", "(\d+)[e|\s]"],
    "wc" : ["WC", "(\d) WC"],
    "shower" : ["eau", "(\d{1})"],
    "bathtub" : ["de bain", "(\d{1})"],
    "room" : ["pièce", "(\d+)"],
    "bedrooms" : ["chambre", "(\d+)"],
}

# %%
column_without_value = {
    "fibre" : "Fibre",
    "cellar" : "cave|Cave",
    "elevator" : "Ascenseur",
    "heater" : "Chauffage",
    "interphone" : "Interphone",
    "view" : "Exposé",
    "guardian" : "Gardien",
    "silent" : "Calme",
    "balcony" : "balcon|Balcon",
    "terrace" : "terrasse|Terrasse",
    "garden" : "Jardin",
    "box" : "box",
    "pool" : "Piscine",
    "garage" : "Garage",
}

# %%
#df_equi.drop(['value'], axis=1, inplace=True, errors='ignore')

# %%
#merged = pd.merge(df_equi, ads, right_on='id', left_on='ad_id')

# %%
def extract_column_value(df, match_str, regex):
    df_equi = df[df["value"].str.contains(match_str)]
    df_equi = df_equi["value"].str.extract(regex, expand=False).str.strip()
    df_equi.fillna(1, inplace=True)
    return df_equi

# %%
extract_column_value(df_equi, "étage", "(\d+)[e|\s]")
# Out:
# 22       6
# 32       1
# 42       1
# 54       1
# 67       1
#         ..
# 20465    2
# 20483    4
# 20496    5
# 20506    5
# 20513    5
# Name: value, Length: 1586, dtype: object

# %%
for column in column_with_value:
    df_equi[column] = extract_column_value(df_equi, column_with_value[column][0], column_with_value[column][1])

# %%
df_equi['ad_id'].unique()
# Out:
# array(['ad_1917', 'ad_1454', 'ad_1794', ..., 'ad_1441', 'ad_380',
#        'ad_534'], dtype=object)

# %%
df = pd.DataFrame(df_equi['ad_id'].unique())

# %%
def merge_column(df, name):
    df = pd.merge(df, df_equi[df_equi[name].notnull()][["ad_id", name]], right_on='ad_id', left_on=0, how='left')
    df.drop(['ad_id'], axis=1, inplace=True, errors='ignore')
    return df

# %%
for c in column_with_value:
    df = merge_column(df, c)

# %%
df
# Out:
#             0 built stage   wc shower bathtub room bedrooms
# 0     ad_1917  1925   NaN    1      1     NaN    2        1
# 1     ad_1454  1860     6    1      1     NaN    3        1
# 2     ad_1794  1949     1    1      1     NaN    2        1
# 3     ad_1519  1870     1  NaN      1     NaN    2        1
# 4     ad_1779  1969     1    1    NaN       1    2        1
# ...       ...   ...   ...  ...    ...     ...  ...      ...
# 1878   ad_741  1970     2    2      1       1    6        4
# 1879  ad_1600  1930     4    2      2       1    5        4
# 1880  ad_1441   NaN     5    1    NaN       1    2        1
# 1881   ad_380   NaN     5  NaN      2     NaN    3        1
# 1882   ad_534   NaN     5  NaN      1     NaN    1        1
#
# [1883 rows x 8 columns]

# %%
merged = pd.merge(merged, df, right_on=0, left_on='id', how='left')

# %%
merged.drop([0], axis=1, inplace=True, errors='ignore')

# %%
merged
# Out:
#            id                                        description  \
# 0     ad_1917  PARIS 17ème. AVENUE NIEL *** Vidéo disponible ...
# 1     ad_1454  Appartement Paris 3 pièce(s) 53 m2. Stéphane P...
# 2     ad_1794  Vente Appartement 2 pièces de 31m² - 75018 Par...
# 3     ad_1519  A vendre, en exclusivité, dans le 11e arrondis...
# 4     ad_1779  Gambetta 2 pièce(s) 40 m2. Rue d'Annam, à quel...
# ...       ...                                                ...
# 1401   ad_412  Paris 11e - SAINT-SÉBASTIEN / FROISSART - Appa...
# 1402   ad_767  Loft d'architecte dans une ancienne ferronneri...
# 1403  ad_1441  Appartement 2 pièces de 46m² | Rue Clisson | P...
# 1404   ad_380  Duplex 3 pièces avec terrasse - Pernety XVIème...
# 1405   ad_534  PARIS 18EME -AVE CLICHY-Idéal 1er achat. PARIS...
#
#                                                  adress  \
# 0     Achat appartement 2 pièces 63 m²Paris 17e 7501...
# 1     Achat appartement 3 pièces 53 m²Paris 18e 7501...
# 2     Achat appartement 2 pièces 31 m²Paris 18e 7501...
# 3     Achat appartement 2 pièces 31 m²Paris 11e 7501...
# 4     Achat appartement 2 pièces 40 m²Paris 20e 7502...
# ...                                                 ...
# 1401  Achat appartement 2 pièces 49 m²Paris 11e 7501...
# 1402  Achat appartement 2 pièces 80 m²Paris 11e 7501...
# 1403  Achat appartement 2 pièces 46 m²Paris 13e 7501...
# 1404  Achat duplex 3 pièces 53 m²Paris 14e 75014 (Pe...
# 1405  Achat appartement 1 pièce 13 m²Paris 18e 75018...
#
#                            date_pub               date_update      price  \
# 0            Publiée le 4 déc. 2021  Modifiée le 30 déc. 2021  640 000 €
# 1           Publiée le 16 déc. 2021  Modifiée le 16 déc. 2021  556 500 €
# 2            Publiée le 8 déc. 2021  Modifiée le 28 déc. 2021  305 000 €
# 3           Publiée le 15 déc. 2021  Modifiée le 29 déc. 2021  380 000 €
# 4           Publiée le 24 nov. 2021  Modifiée le 29 déc. 2021  368 000 €
# ...                             ...                       ...        ...
# 1401  Publiée il y a plus de 2 mois   Modifiée le 6 déc. 2021  520 000 €
# 1402  Publiée il y a plus de 2 mois  Modifiée le 30 déc. 2021  850 000 €
# 1403        Publiée le 16 déc. 2021                       NaN  441 000 €
# 1404  Publiée il y a plus de 2 mois  Modifiée le 18 déc. 2021  785 000 €
# 1405        Publiée le 24 nov. 2021  Modifiée le 18 déc. 2021  165 000 €
#
#                                                     fee   bus  metro  \
# 0                     Honoraires à la charge du vendeur   6.0    0.0
# 1     Honoraires : 5,00% TTC inclus à la charge de l...   7.0    0.0
# 2                     Honoraires à la charge du vendeur   5.0    1.0
# 3     Honoraires : 4,40% TTC inclus à la charge de l...   7.0    1.0
# 4     Honoraires : 5,14% TTC inclus à la charge de l...  12.0    0.0
# ...                                                 ...   ...    ...
# 1401                  Honoraires à la charge du vendeur   7.0    1.0
# 1402                  Honoraires à la charge du vendeur   7.0    0.0
# 1403                  Honoraires à la charge du vendeur   6.0    0.0
# 1404  Honoraires : 4,67% TTC inclus à la charge de l...   4.0    1.0
# 1405                  Honoraires à la charge du vendeur   9.0    1.0
#
#       Autolib'  ...  Terrain et Salle de sport  Théâtre  Vélib'  built  stage  \
# 0          6.0  ...                        4.0      1.0     9.0   1925    NaN
# 1          1.0  ...                        4.0      0.0     3.0   1860      6
# 2          5.0  ...                        4.0      2.0     9.0   1949      1
# 3          7.0  ...                       10.0      3.0    16.0   1870      1
# 4          9.0  ...                       15.0      3.0    15.0   1969      1
# ...        ...  ...                        ...      ...     ...    ...    ...
# 1401       7.0  ...                       10.0      3.0    16.0   1880      1
# 1402       4.0  ...                        6.0      0.0    11.0    NaN      2
# 1403       5.0  ...                       11.0      1.0     8.0    NaN      5
# 1404       3.0  ...                        9.0      0.0    10.0    NaN      5
# 1405       1.0  ...                        6.0      1.0     7.0    NaN      5
#
#        wc  shower  bathtub  room  bedrooms
# 0       1       1      NaN     2         1
# 1       1       1      NaN     3         1
# 2       1       1      NaN     2         1
# 3     NaN       1      NaN     2         1
# 4       1     NaN        1     2         1
# ...   ...     ...      ...   ...       ...
# 1401    1       1      NaN     2         1
# 1402    1     NaN        1     2         1
# 1403    1     NaN        1     2         1
# 1404  NaN       2      NaN     3         1
# 1405  NaN       1      NaN     1         1
#
# [1406 rows x 50 columns]

# %%
merged.drop(['date_pub', 'date_update', 'fee'], axis=1, inplace=True, errors='ignore')

# %%
merged
# Out:
#            id                                        description  \
# 0     ad_1917  PARIS 17ème. AVENUE NIEL *** Vidéo disponible ...
# 1     ad_1454  Appartement Paris 3 pièce(s) 53 m2. Stéphane P...
# 2     ad_1794  Vente Appartement 2 pièces de 31m² - 75018 Par...
# 3     ad_1519  A vendre, en exclusivité, dans le 11e arrondis...
# 4     ad_1779  Gambetta 2 pièce(s) 40 m2. Rue d'Annam, à quel...
# ...       ...                                                ...
# 1401   ad_412  Paris 11e - SAINT-SÉBASTIEN / FROISSART - Appa...
# 1402   ad_767  Loft d'architecte dans une ancienne ferronneri...
# 1403  ad_1441  Appartement 2 pièces de 46m² | Rue Clisson | P...
# 1404   ad_380  Duplex 3 pièces avec terrasse - Pernety XVIème...
# 1405   ad_534  PARIS 18EME -AVE CLICHY-Idéal 1er achat. PARIS...
#
#                                                  adress      price   bus  \
# 0     Achat appartement 2 pièces 63 m²Paris 17e 7501...  640 000 €   6.0
# 1     Achat appartement 3 pièces 53 m²Paris 18e 7501...  556 500 €   7.0
# 2     Achat appartement 2 pièces 31 m²Paris 18e 7501...  305 000 €   5.0
# 3     Achat appartement 2 pièces 31 m²Paris 11e 7501...  380 000 €   7.0
# 4     Achat appartement 2 pièces 40 m²Paris 20e 7502...  368 000 €  12.0
# ...                                                 ...        ...   ...
# 1401  Achat appartement 2 pièces 49 m²Paris 11e 7501...  520 000 €   7.0
# 1402  Achat appartement 2 pièces 80 m²Paris 11e 7501...  850 000 €   7.0
# 1403  Achat appartement 2 pièces 46 m²Paris 13e 7501...  441 000 €   6.0
# 1404  Achat duplex 3 pièces 53 m²Paris 14e 75014 (Pe...  785 000 €   4.0
# 1405  Achat appartement 1 pièce 13 m²Paris 18e 75018...  165 000 €   9.0
#
#       metro  Autolib'  Banque   Bar  Boucherie  ...  \
# 0       0.0       6.0    11.0   4.0        6.0  ...
# 1       0.0       1.0     1.0   4.0        0.0  ...
# 2       1.0       5.0     1.0  10.0        7.0  ...
# 3       1.0       7.0    18.0  26.0        4.0  ...
# 4       0.0       9.0    12.0  13.0        5.0  ...
# ...     ...       ...     ...   ...        ...  ...
# 1401    1.0       7.0    18.0  26.0        4.0  ...
# 1402    0.0       4.0     6.0  11.0        3.0  ...
# 1403    0.0       5.0     6.0   5.0        2.0  ...
# 1404    1.0       3.0     4.0   5.0        2.0  ...
# 1405    1.0       1.0     5.0   8.0        1.0  ...
#
#       Terrain et Salle de sport  Théâtre  Vélib'  built  stage   wc  shower  \
# 0                           4.0      1.0     9.0   1925    NaN    1       1
# 1                           4.0      0.0     3.0   1860      6    1       1
# 2                           4.0      2.0     9.0   1949      1    1       1
# 3                          10.0      3.0    16.0   1870      1  NaN       1
# 4                          15.0      3.0    15.0   1969      1    1     NaN
# ...                         ...      ...     ...    ...    ...  ...     ...
# 1401                       10.0      3.0    16.0   1880      1    1       1
# 1402                        6.0      0.0    11.0    NaN      2    1     NaN
# 1403                       11.0      1.0     8.0    NaN      5    1     NaN
# 1404                        9.0      0.0    10.0    NaN      5  NaN       2
# 1405                        6.0      1.0     7.0    NaN      5  NaN       1
#
#       bathtub  room  bedrooms
# 0         NaN     2         1
# 1         NaN     3         1
# 2         NaN     2         1
# 3         NaN     2         1
# 4           1     2         1
# ...       ...   ...       ...
# 1401      NaN     2         1
# 1402        1     2         1
# 1403        1     2         1
# 1404      NaN     3         1
# 1405      NaN     1         1
#
# [1406 rows x 47 columns]

# %%
merged['district'] = merged['adress'].str.extract('(\d+)e', expand=False).str.strip()

# %%
merged['volume'] = merged['adress'].str.extract('(\d+).?m²', expand=False).str.strip()

# %%
merged['rooms'] = merged['adress'].str.extract('(\d+).?[p|P][i|I]', expand=False).str.strip()

# %%
merged.loc[merged['description'].str.contains('(?i)STUDIO') & merged['rooms'].isna(), 'rooms'] = 1

# %%
merged['price'] = merged['price'].str.replace(u'\xa0', '').str.replace('€', '').astype(int)

# %%
merged.loc[1606, 'volume'] = 61
merged.loc[1606, 'district'] = 18

# %%
merged.columns
# Out:
# Index(['id', 'description', 'adress', 'price', 'bus', 'metro', 'Autolib'',
#        'Banque', 'Bar', 'Boucherie', 'Boulangerie', 'Bureau de poste',
#        'Cinéma', 'Collège', 'Crèche', 'Ecole maternelle', 'Ecole primaire',
#        'Enseignement supérieur', 'Gare ferroviaire', 'Hôpital',
#        'Location de vélo', 'Ludothèque', 'Lycée', 'Marché de quartier',
#        'Monument historique', 'Médecin généraliste', 'Médecin spécialiste',
#        'Parc, Jardin et Square', 'Parking', 'Pharmacie', 'Presse et Tabac',
#        'Restaurant', 'Salle de musculation / cardiotraining',
#        'Station de taxi', 'Station service', 'Supermarché et Hypermarché',
#        'Supérette', 'Terrain et Salle de sport', 'Théâtre', 'Vélib'', 'built',
#        'stage', 'wc', 'shower', 'bathtub', 'room', 'bedrooms', 'district',
#        'volume', 'rooms'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.heatmap(merged.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
merged = merged[['price', 'bus', 'metro', "Autolib'",
       'Banque', 'Bar', 'Boucherie', 'Boulangerie', 'Bureau de poste',
       'Cinéma', 'Collège', 'Crèche', 'Ecole maternelle', 'Ecole primaire',
       'Enseignement supérieur', 'Gare ferroviaire', 'Hôpital',
       'Location de vélo', 'Ludothèque', 'Lycée', 'Marché de quartier',
       'Monument historique', 'Médecin généraliste', 'Médecin spécialiste',
       'Parc, Jardin et Square', 'Parking', 'Pharmacie', 'Presse et Tabac',
       'Restaurant', 'Salle de musculation / cardiotraining',
       'Station de taxi', 'Station service', 'Supermarché et Hypermarché',
       'Supérette', 'Terrain et Salle de sport', 'Théâtre', "Vélib'", 'built',
       'stage', 'wc', 'shower', 'bathtub', 'room', 'bedrooms', 'district',
       'volume', 'rooms']].apply(pd.to_numeric)

# %%
merged
# Out:
#          price   bus  metro  Autolib'  Banque   Bar  Boucherie  Boulangerie  \
# 0     640000.0   6.0    0.0       6.0    11.0   4.0        6.0          9.0
# 1     556500.0   7.0    0.0       1.0     1.0   4.0        0.0          3.0
# 2     305000.0   5.0    1.0       5.0     1.0  10.0        7.0          9.0
# 3     380000.0   7.0    1.0       7.0    18.0  26.0        4.0         18.0
# 4     368000.0  12.0    0.0       9.0    12.0  13.0        5.0         16.0
# ...        ...   ...    ...       ...     ...   ...        ...          ...
# 1402  850000.0   7.0    0.0       4.0     6.0  11.0        3.0          5.0
# 1403  441000.0   6.0    0.0       5.0     6.0   5.0        2.0          4.0
# 1404  785000.0   4.0    1.0       3.0     4.0   5.0        2.0         13.0
# 1405  165000.0   9.0    1.0       1.0     5.0   8.0        1.0         10.0
# 1606       NaN   NaN    NaN       NaN     NaN   NaN        NaN          NaN
#
#       Bureau de poste  Cinéma  ...   built  stage   wc  shower  bathtub  room  \
# 0                 2.0     0.0  ...  1925.0    NaN  1.0     1.0      NaN   2.0
# 1                 1.0     0.0  ...  1860.0    6.0  1.0     1.0      NaN   3.0
# 2                 2.0     0.0  ...  1949.0    1.0  1.0     1.0      NaN   2.0
# 3                 2.0     0.0  ...  1870.0    1.0  NaN     1.0      NaN   2.0
# 4                 3.0     1.0  ...  1969.0    1.0  1.0     NaN      1.0   2.0
# ...               ...     ...  ...     ...    ...  ...     ...      ...   ...
# 1402              1.0     0.0  ...     NaN    2.0  1.0     NaN      1.0   2.0
# 1403              1.0     2.0  ...     NaN    5.0  1.0     NaN      1.0   2.0
# 1404              1.0     1.0  ...     NaN    5.0  NaN     2.0      NaN   3.0
# 1405              2.0     2.0  ...     NaN    5.0  NaN     1.0      NaN   1.0
# 1606              NaN     NaN  ...     NaN    NaN  NaN     NaN      NaN   NaN
#
#       bedrooms  district  volume  rooms
# 0          1.0      17.0    63.0    2.0
# 1          1.0      18.0    53.0    3.0
# 2          1.0      18.0    31.0    2.0
# 3          1.0      11.0    31.0    2.0
# 4          1.0      20.0    40.0    2.0
# ...        ...       ...     ...    ...
# 1402       1.0      11.0    80.0    2.0
# 1403       1.0      13.0    46.0    2.0
# 1404       1.0      14.0    53.0    3.0
# 1405       1.0      18.0    13.0    1.0
# 1606       NaN      18.0    61.0    NaN
#
# [1407 rows x 47 columns]

# %%
merged["built"] = merged["built"].fillna(method = 'pad')

# %%
merged = merged.fillna(0)

# %%
df_district = pd.get_dummies(merged['district'])

# %%
merged.drop(['district'], axis=1, inplace=True, errors='ignore')

# %%
merged = pd.concat([merged, df_district], axis=1)

# %%
X = merged.loc[:, merged.columns != 'price']
y = merged[["price"]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import xgboost
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
classifier = xgboost.XGBRegressor()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
from datetime import datetime
# Here we go
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(X_train, y_train)
timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# c:\users\prasanth\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   category=UserWarning,
#  Time taken: 0 hours 0 minutes and 4.03 seconds.

# %%
random_search.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, enable_categorical=False,
#              gamma=0.0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.25, max_delta_step=0,
#              max_depth=5, min_child_weight=5, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
classifier = xgboost.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.4, enable_categorical=False,
             gamma=0.2, gpu_id=-1, importance_type=None,
             interaction_constraints='', learning_rate=0.2, max_delta_step=0,
             max_depth=12, min_child_weight=5, missing=1,
             monotone_constraints='()', n_estimators=100, n_jobs=8,
             num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
             validate_parameters=1, verbosity=None)

# %%
classifier.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, enable_categorical=False,
#              gamma=0.2, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.2, max_delta_step=0,
#              max_depth=12, min_child_weight=5, missing=1,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = classifier.predict(X_test)

# %%
plt.scatter(np.arange(0,y_test.shape[0]).reshape(y_test.shape), y_test)
plt.scatter(np.arange(0,y_test.shape[0]).reshape(y_test.shape), y_pred)

# %%
f, ax = plt.subplots()
ax.scatter(y_test, y_pred, c='.2')
plt.axline((0, 0), slope=1, color="red", linestyle=(0, (5, 5)))

plt.show()

# %%
sns.displot((y_test - y_pred.reshape(y_pred.shape[0], 1)), bins=50, kde=True)

# %%
r2_score = classifier.score(X_test.values,y_test.values)
print(r2_score*100,'%')
# Out:
# 99.434095751513 %

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 20390.9101285461
# MSE: 1958656804.737834
# RMSE: 44256.71479829738

# %%
test = pd.DataFrame(y_test)

# %%
test['pred'] = y_pred.astype(int)

# %%
test
# Out:
#           price     pred
# 291   1095000.0  1099672
# 1302   378000.0   377470
# 1020   198000.0   209141
# 2      305000.0   302549
# 501    750000.0   736548
# ...         ...      ...
# 483   1160000.0  1166217
# 954    750000.0   637448
# 753    925000.0   945029
# 85     845000.0   859355
# 56     405000.0   404973
#
# [423 rows x 2 columns]
